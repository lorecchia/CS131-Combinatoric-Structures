# %% [markdown]
# # Lecture 3: Logical Equivalences I

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# import libraries
import numpy as np
import matplotlib as mp
import pandas as pd
import matplotlib.pyplot as plt
import laUtilities as ut
import slideUtilities as sl
import demoUtilities as dm
import prettytable
from IPython.display import Image
from IPython.display import display_html
from IPython.display import display
from IPython.display import Math
from IPython.display import Latex
from truths import Truths
#reload(dm)
#reload(ut)
#print('')

# %%
# %%html
# <style>
#  .container.slides .celltoolbar, .container.slides .hide-in-slideshow {
#     display: None ! important;
# }
# </style>
# Out:
# <style>
#  .container.slides .celltoolbar, .container.slides .hide-in-slideshow {
#     display: None ! important;
# }
# </style>

# %% [markdown]
# Lecture Summary:
#
# 1. Recap of last lecture: propositions, basic operators, (not, and ,or), truth tables.
# 2. Recap of last lecture: conditional statements: implication, equivalence
# x - filling in large truth tables, examples
#
# x - number of operatoprs+tautology
#
# x - reading: english vs implication,
#
# x - precedence of operators
# examples
#
#
# More examples please: on the board
# More questions: 4
#
# logical equivalences:
# converse, contrapositive, inverse etc.
# - show equivalences
#
# other equivalences
# list
# examples
# use, fasteer than truthtable
# example de morgan's
#
# Analogies with set theory
# propositional functions
# sets, truth sets
#
# Reading on sets: Rosen 2.1 and 2.2
#
# Homework, HTPI from last year + functionally complete + more?

# %% [markdown]
# ## Recap of Lecture 2
#
# - introduction to propositional logic
# - propositions: can take T or F value
# - logical operators (aka logical connectives): used to build propositions from other propositions
# - truth tables: express truth values of compound propositions

# %% [markdown]
# - common logical operators
#
#     * NEGATION: $\neg P$,
#     * DISJUNCTION: $P \lor Q$,
#     * CONJUNCTION: $P \land Q$.
#
# - operators for conditional statements
#
#     * IMPLICATION: $P \implies Q$
#     * EQUIVALENCE: $P \iff Q$

# %% [markdown]
# ## Lecture 2 Add-on: Recognizing conditional statements
#
# Many different ways of expressing the implication $P \implies Q$ in English. Familiarize yourself.
#
# List in the textbook:
# - if P, then Q
# - P implies Q
# - if P, Q
# - P only if Q
# - Q unless  $\neg P$
# - Q when P
# - Q if P
# - Q whenever P
# - P is sufficient for Q
# - Q follows from P
# - Q is necessary for P
# - a necessary condition for P is Q
# - a sufficient condition for Q is P

# %% [markdown]
# **Clicker Question 1:**
#
# Match each English sentence to its logical meaning:
#
# English sentences:
#
#   1. $Q$ only if $P$
#   2. $P$ is a necessary and sufficient condition for $Q$
#   3. $Q$ holds whenever $\neg P$
#   4. unless $P$, $\neg Q$ holds
#
# Possible logical meanings (same can repeat!):
#
#   * a) $Q \implies P$
#   * b) $P \implies Q$
#   * c) $P \iff Q$
#   * d) $\neg P \implies Q$

# %% [markdown]
# Answer:
#     1 --> a
#     2 --> c
#     3 --> d
#     4 --> a

# %% [markdown]
# ## Lecture 2 Add-on: Operators and Truth Tables
#
#
# ** Clicker Question 2**:
# Suppose we are writing down, the truth table for a compound proposition of the propositional variables $P$ and $Q$.
# How many rows does it have?
# * a) 1 rows
# * b) 2 rows
# * c) 4 rows
# * d) 8 rows
# * e) it depends on the number of operators in the compound proposition

# %% [markdown]
# ** Answer **: 4 rows, as there are two truth assignments for $P$ and true for $Q$, yielding $4$ possible cases.

# %% [markdown]
# **Clicker Question 3)**:
#
# How many distinct binary logical operators are there? _Hint_: each operator corresponds to a different truth table.
# * a) 4 operators
# * b) 8 operators
# * c) 16 operators
# * d) 64 operators
# * e) infinitely many

# %% [markdown]
# **Answer**: 16 operators.
#
# Each operator corresponds to a truth table with 4 rows and is completely specified by the truth assignment to these rows. For each row, there are 2 choices. Hence, there are $2^4 = 16$ possible operators.

# %% [markdown]
# **How many binary operators have we seen so far?**:
# List compiled by students
#     - $\lor$
#     - $\land$
#     - $\implies$
#     - exclusive or
#     - $\iff$
#     - false
#     -the negations of the above operators
# Total: 12

# %% [markdown]
# The remaining ones are:
# - the operator that just returns the first term.
# - the operator that just returns the second term.
# - their negations
#
# Check out the whole list here:
# https://en.wikipedia.org/wiki/Truth_table#Binary_operations

# %% [markdown]
# ## Lecture 2 Add-on: Precedence of Operators
#
# Last lecture I have tried to be careful and avoid writing things like
# $$
# \neg P \lor Q
# $$
# because they are ambiguous.

# %% [markdown]
# Does it mean
# $$(\neg P) \lor Q$$
# or
# $$\neg (P \lor Q)  ?$$

# %% [markdown]
# **Precedence of Operators**: negation beats dis/conjunction beats conditionals

# %%
# image credit: Kenneth Rosen "Discrete Mathematics and Its Applications 7th ed"
sl.hide_code_in_slideshow()
display(Image("images/L03/opprecedence.png", width=350))
# Out:
# <div id="6184d9ba82924e26"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#6184d9ba82924e26");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>

# %% [markdown]
# ## Lecture 3: Logical Equivalences
#
# **Last time**: Two compound propositions are logically equivalent if they take the same truth value under all truth settings of the propositional variables, i.e., they have the same truth table.

# %% [markdown]
# **Example**: $P \implies Q$ is logically equivalent to $\neg P \lor Q$.
#
# We established this by computing the truth tables of both compound propositions.

# %% [markdown]
# ## Lecture 3: Logical Equivalences
#
# **Last time**: Two compound propositions are logically equivalent if they take the same truth value under all truth settings of the propositional variables, i.e., they have the same truth table.
#
# **Different definition**: Two propositions $R$ and $S$ are logically equivalent if
# $$
# R \iff S
# $$
# is a tautology (always true).

# %% [markdown]
# **Example**:
# $$[(\neg P) \lor Q] \iff [P \implies Q] $$
# is a tautology

# %% [markdown]
# ## L02's ending question
#
# **Clicker Question**: How many T's are there in the truth table for the compound proposition:
# $$
# [(\neg P) \lor Q] \iff [P \implies Q]
# $$
#
# a. 0
# b. 1
# c. 2
# d. 3
# e. 4

# %% [markdown]
# **Answer**: Statement is a tautology, so all 4 rows will be true.

# %% [markdown]
# ## Why Logical Equivalences?

# %% [markdown]
# 1. simplify expressions
# 2. develop boolean algebra and boolean calculus
# 3. reason about logic formally

# %% [markdown]
# ## Important Logical Equivalences
#
# \1. Basic equivalences
#     - Identity laws
#     - domination laws
#     - idempotent laws
#     - negation laws
#     - double negation laws

# %% [markdown]
# \2. Properties of conjunctions and disjunctions
#     * Commutative Laws
#     * Associative Laws
#     * Distributive Laws

# %% [markdown]
# ## Important and Interesting Logical Equivalences
#
# - De Morgan's Laws
#
# - Equivalences Involving Conditional Statemetns

# %%
# image credit: Kenneth Rosen "Discrete Mathematics and Its Applications 7th ed"
sl.hide_code_in_slideshow()
display(Image("images/L03/demorgan.png", width=2000))
# Out:
# <div id="b7a1b06bc630e96c"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#b7a1b06bc630e96c");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>

# %% [markdown]
# **Example:**
#
#     Both the Yankees and the Red Sox lost last night.
#
# Its negation is:
#
#     Either the Yankees or the Red Sox won last night.

# %% [markdown]
# ## Equivalences involving conditional statements
#
# Statement: $P \implies Q$
# Converse:  $Q \implies P$

# %%
# image credit: Kenneth Rosen "Discrete Mathematics and Its Applications 7th ed"
sl.hide_code_in_slideshow()
display(Image("images/L02/circuit.png", width=350))
# Out:
# <div id="2d2abfc7798c0116"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#2d2abfc7798c0116");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>

# %% [markdown]
# ## Mathematical Proofs

# %% [markdown]
# In mathematical proofs (and logical deduction in general), we start with some assumptions (i.e., premises) and derive some theses (i.e., conclusions).
#
# A MATHEMATICAL PROOF:
# __ASSUMPTION__ $P \implies P_1 \implies P_2 \implies P_3 \implies P_4 \implies C$ __THESIS__
#
# To complete the proof, we must verify that all the implications are valid (i.e., true). That means, we must check that indeed:
# - $P \implies P_1$,
# - $P_1 \implies P_2$,
# - $P_2 \implies P_3$,
# - $P_3 \implies P_4$,
# ...
# Each of these steps may require a mathematical proof itself.

# %% [markdown]
# Where does this stop?
#
# - Axioms

# %% [markdown]
# ## Lecture 2 Add-on: Conditional relations between two propositions
#
# Given two propositions $P$ and $Q$, we have seen that they can be conditionally related in different ways.
