# %% [markdown]
# # Welcome to CS131

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# import libraries
import numpy as np
import matplotlib as mp
import pandas as pd
import matplotlib.pyplot as plt
import laUtilities as ut
import slideUtilities as sl
import demoUtilities as dm
from IPython.display import Image
from IPython.display import display_html
from IPython.display import display
from IPython.display import Math
from IPython.display import Latex
#reload(dm)
#reload(ut)
#print('')

# %%
# %%html
# <style>
#  .container.slides .celltoolbar, .container.slides .hide-in-slideshow {
#     display: None ! important;
# }
# </style>
# Out:
# <style>
#  .container.slides .celltoolbar, .container.slides .hide-in-slideshow {
#     display: None ! important;
# }
# </style>

# %% [markdown]
# Set up useful MathJax (Latex) macros.
# See http://docs.mathjax.org/en/latest/tex.html#defining-tex-macros
# $\newcommand{\mat}[1]{\left[\begin{array}#1\end{array}\right]}$
# $\newcommand{\x}{{\mathbf x}}$
# $\newcommand{\b}{{\mathbf b}}$
# $\newcommand{\R}{{\mathbb{R}}}$
#
# $\require{extension}$
# Another useful extension is bbox.  See doc.

# %% [markdown]
# Combinatoric Structures: "Mathematics for Computer Science"

# %% [markdown]
# Course goals:
# 1. Designing and writing mathematical proofs,
# 2. Mastering basic __discrete__ math concepts for Computer Science

# %% [markdown]
# Students sometimes find this course _hard_.
# There is one simple explanation:

# %%
sl.hide_code_in_slideshow()
display(Image("images/pisa15math.png", width=550))
# Out:
# <div id="e0210c918d4f751a"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#e0210c918d4f751a");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>

# %% [markdown]
# ## Logistics

# %% [markdown]
# * Professor Lorenzo Orecchia
# * Email: orecchia@bu.edu
# * Office: MCS 135D
# * Office Hours: M11-12

# %% [markdown]
# * Teaching Fellow: Ms. Hannah Flynn
# * Email: hmflynn@bu.edu
# * Office Hours Location: CS Undegraduate Lab
# * Office Hours: Th 2-3.30pm, TBD

# %% [markdown]
# > More TAs will be available for tutoring and office hours. Stay tuned

# %% [markdown]
# ## Important Webpages
#
# * Course homepage: `http://cs-people.bu.edu/orecchia/cs131/course.html`
#     * Summary of course policies, syllabus
# * _Piazza_ homepage: `https://piazza.com/bu/spring2017/cs131/home`
#     * Used for **all** communications. Lecture notes and homework repository.
# * _Blackboard_ homepage: login to `learn.bu.edu`
#     * Used for gradekeeping

# %% [markdown]
# ## Textbook

# %% [markdown]
# **Required Textbook**: `Discrete Mathematics and Its Applications (7th ed.)` by Kenneth Rosen
#
# - A comprehensive reference with loads of exercises

# %%
sl.hide_code_in_slideshow()
display(Image("images/rosen.jpg", width=550))
# Out:
# <div id="a965e95695fdb920"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#a965e95695fdb920");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>

# %% [markdown]
# **Optional Textbook**: `How To Prove It: A Structured Approach (2nd ed.)` by Daniel J. Velleman
#
# - Recommended if you have no experience with mathematical proofs

# %%
sl.hide_code_in_slideshow()
display(Image("images/velleman.jpg", width=550))
# Out:
# <div id="70baadca439bc034"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#70baadca439bc034");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>

# %% [markdown]
# ## Classwork
#
# ### Homework
# - Weekly assignments due on Thursday at noon in CS Homework dropbox on the first floor of MCS
# - Graded homeworks will be returned on the shelves above the dropbox
# - New homework will be out on Thursday night - a short one will be out tonight
# - No homework on midterm weeks
# **NEW THIS YEAR**: `FERPA` does not allow us to leave identifiable graded material unattended. As a result, you will be assigned a _random number_, which will serve as your identifier for the rest of the class.
# > Mark your homeworks with this and only this identifier.

# %% [markdown]
# ### Two In-class Midterm Exams
# - February 16
# - March 23
#
# ### Final Exam
# - Scheduled by College; Date/Location TBA

# %% [markdown]
# ### Grading
#
# - Problem sets: 20\%
# - Midterms: 40\%
# - Final exam: 35\%
# - Participation: 5\%

# %% [markdown]
# > FINAL GRADES: Is there a curve?

# %% [markdown]
# Answer: It's complicated...
#     - All components are scored without a curve (absolute scores)
#     - The total final score is turned into a letter grade by combining the relative score (i.e., curved) with a small contribution from the absolute score

# %% [markdown]
# To make life easier: I will strive to give you a *predicted letter grade* after each midterm exam, i.e., before the drop deadlines.

# %% [markdown]
# ## Course Help
#
# - Labs:
#     - Solve practice problems in groups
#     - Get your questions answered by TF
# - Tutoring hours:
#     - We will have 1-2 UAs providing help. Times TBD.
# - Piazza:
#     - First place to get help from us and from your peers!
#
# > Who should I contact if I have a question about course material or administration?
#
# 1. Ask on Piazza if not private
# 2. Google it!
# 3. Ask UAs (only for course material)
# 4. Ask TF (course material __AND__ administration)

# %% [markdown]
# (5). Of course, if nothing really works, you may ask me :)

# %% [markdown]
# ## Lecture in this class
#
# ### Traditional lecture
# * The instructor summarizes what you need to know.
# * Readings are assigned, but may not actually be done!

# %%
# image credit: Dave Sullivan
sl.hide_code_in_slideshow()
display(Image("images/Traditional-Lecture.png", width=400))
# Out:
# <div id="a39eb9f3881ea27d"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#a39eb9f3881ea27d");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>

# %% [markdown]
# > __Lecture:__ The process of transferring notes from the teacher to the student without passing through the minds of either.

# %% [markdown]
# ### Limitations of the traditional approach
#
# * You get little or no immediate feedback
# * In reality, little is actually learned from passive listening.
#     * You need to actively engage with the material
# * Homework provides active engagement, but ...
# * After college, you'll need to continue learning on your own.
#     * Should get good now at learning from a textbook.

# %% [markdown]
# ## Benefits of Peer Instruction

# %% [markdown]
# * Based on an approach called _peer instruction_
#     * Developed by Eric Mazur at Harvard
# * Basic process:
#     1. Question posed (possibly after a short intro)
#     2. Solo vote (no discussion yet)
#     3. Small-group discussions (in teams of 3)
#         * explain your thinking to each other
#         * come to a consensus
#     4. Group vote
#         * each person in the group enters the same answer
#     5. Class-wide discussion
#         * Why is the correct answer correct?
#         * Why are the wrong answers wrong?
#         * Possibly some clarification by me

# %% [markdown]
# But the real reason is:
#
# * It promotes increased learning.
#     * Explaining concepts to others benefits you!

# %%
sl.hide_code_in_slideshow()
display(Image("images/PI-Benefits-Chart-Mazur.png", width=550))
# Out:
# <div id="5f2eb9bce7e2276e"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#5f2eb9bce7e2276e");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>

# %% [markdown]
# > Crouch, C., Mazur, E. _Peer Instruction: Ten years of experience and results._

# %% [markdown]
# ## Clickers
#
# - For this to work, you need a TurningPoint license and a clicker or your smartphone.
#     * I will post instructions on how to get set up on Piazza. You should have your clicker/license by next Tuesday.

# %% [markdown]
# ## End of Logistics
# ### A task list for you
#
# By Tuesday:
# [] If you do not have one already, get a TurningPoint clicker/clicker license from the bookstore.
# [] Set up your clicker or smartphone (I will post instructions on Piazza).
# [] Come to class ready to click!
#
# By Thursday:
# [] Make sure you have access to required textbook.
# [[ Complete Homework 0 (To be posted tonight).
#
# And don't forget:
# [] Labs start on this Wednesday. Please attend the lab you have been assigned to. The rooms are small and close to capacity.
